# %%
import pandas as pd
import numpy as np

pd.set_option("mode.copy_on_write", True)

# %%
jan_2023 = pd.read_csv("../100_data/101_raw/ev_jan_june_2023.csv")
jan_2023.sample()
# Out:
#                 Keyword  \
# 5329  electric vehicles
#
#                                                                                                   Post_URL  \
# 5329  https://x.com/search?q="electric vehicles" lang:en until:2023-02-18 since:2023-02-17&src=typed_query
#
#                   Author_Name    Author_Web_Page_URL Author_Handle  \
# 5329  Drax Electric Vehicles⚡  https://x.com/DraxEVs       DraxEVs
#
#      Verified_Status                   UTC_Time    Ads  \
# 5329           False  2023-02-17 15:46:01+00:00  False
#
#                                                                                                                                                 Tweet_Content  \
# 5329  From the project team to the plan and justification, here's what you should include in your business case for electrification 👇 https://t.co/eGCvFlO3JK
#
#            Post_ID  ...  Like_Count  View_Count  Bookmark_Count  \
# ...

# %%
train = jan_2023.sample(25, random_state=30).index
train
# Out:
# Index([2695, 4075, 6034, 4279,  514, 2978, 2001,  882,  867,  518, 5337, 5617,
#        5726, 4708,  362,  472,  311, 5020, 2476, 6360, 1928,  731, 2649, 6222,
#        5208],
#       dtype='int64')

# %%
pd.set_option("display.max_colwidth", None)
jan_2023.iloc[train, :][["UTC_Time", "Tweets"]]
# Out:
#                        UTC_Time  \
# 2695  2023-01-26 18:04:09+00:00
# 4075  2023-02-07 15:00:02+00:00
# 6034  2023-02-24 14:52:08+00:00
# 4279  2023-02-09 18:04:06+00:00
# 514   2023-01-06 15:36:34+00:00
# 2978  2023-01-28 21:05:40+00:00
# 2001  2023-01-21 15:49:00+00:00
# 882   2023-01-10 20:35:26+00:00
# 867   2023-01-10 21:57:08+00:00
# 518   2023-01-07 05:53:38+00:00
# 5337  2023-02-17 08:34:45+00:00
# 5617  2023-02-20 16:26:55+00:00
# 5726  2023-02-20 12:00:11+00:00
# 4708  2023-02-12 17:50:20+00:00
# 362   2023-01-05 19:21:13+00:00
# 472   2023-01-06 16:07:21+00:00
# 311   2023-01-04 21:32:28+00:00
# 5020  2023-02-15 18:13:26+00:00
# 2476  2023-01-24 21:46:46+00:00
# 6360  2023-03-01 21:43:09+00:00
# 1928  2023-01-20 14:33:07+00:00
# 731   2023-01-09 16:56:12+00:00
# 2649  2023-01-25 16:04:01+00:00
# 6222  2023-02-27 15:27:25+00:00
# 5208  2023-02-17 19:38:06+00:00
#
# ...

# %%
train_manual_labels = [
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Negative",
    "Negative",
    "Negative",
    "Neutral",
    "Neutral",
    "Positive",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Negative",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
]
assert len(train_manual_labels) == 25

# %%
jan_2023.loc[train, "Manual_Training_Labels"] = train_manual_labels

# %%
jan_2023["Is_Training"] = jan_2023["Manual_Training_Labels"].isna().astype(int)

# %%
jan_2023.loc[train][["Tweet_Content", "Is_Training", "Manual_Training_Labels"]]
# Out:
#                                                                                                                                                                                                                                                                                                           Tweet_Content  \
# 2695                              I've written before about how getting more people on buses and e-bikes is faster and cheaper than swapping gas cars for EVs, but reporting this story helped me think in a new way about how to nudge those changes by treating batteries like a public good  https://t.co/dZrMDJp1lK
# 4075                                                                                                                                                                                                     The mineral is critical in the production of batteries for electric vehicles. $ALB $PLL\n\nRead more for free:
# ...

# %% [markdown]
# # Testing Labels for Jan - June 2023

# %%
test = jan_2023.sample(13, random_state=40).index
test
# Out:
# Index([4055, 703, 3391, 369, 6216, 5591, 6375, 2701, 2581, 6386, 3879, 2415,
#        3039],
#       dtype='int64')

# %%
assert len(set(train).intersection(set(test))) == 0  # Make sure no overlap

# %%
pd.set_option("display.max_colwidth", None)
jan_2023.iloc[test, :][["UTC_Time", "Tweet_Content"]]
# Out:
#                        UTC_Time  \
# 4055  2023-02-07 21:50:11+00:00
# 703   2023-01-09 17:30:07+00:00
# 3391  2023-02-01 17:30:30+00:00
# 369   2023-01-06 13:08:43+00:00
# 6216  2023-02-27 13:39:22+00:00
# 5591  2023-02-20 22:18:10+00:00
# 6375  2023-03-02 17:04:03+00:00
# 2701  2023-01-26 12:00:30+00:00
# 2581  2023-01-25 16:01:42+00:00
# 6386  2023-03-02 17:10:00+00:00
# 3879  2023-02-06 16:25:21+00:00
# 2415  2023-01-24 18:50:23+00:00
# 3039  2023-01-29 12:08:02+00:00
#
#                                                                                                                                                                                                                                                                                                          Tweet_Content
# ...

# %%
test_manual_labels = [
    "Positive",
    "Neutral",
    "Neutral",
    "Neutral",
    "Positive",
    "Neutral",
    "Positive",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
]
assert len(test_manual_labels) == 13

# %%
jan_2023.loc[test, "Manual_Testing_Labels"] = test_manual_labels
jan_2023["Is_Testing"] = jan_2023["Manual_Testing_Labels"].isna().astype(int)
jan_2023.loc[test][["Tweet_Content", "Is_Testing", "Manual_Testing_Labels"]]
# Out:
#                                                                                                                                                                                                                                                                                                          Tweet_Content  \
# 4055                                                                #ICYMI: Virginia LCV's Mike Town in @RTDNEWS:\n\n"Electric vehicles are our future. Youngkin can either accept this as fact or put himself further out of touch with reality and his constituents..."\n\n🔗 Read more here: https://t.co/fupicvElOJ
# 703   Hyundai isn’t putting all of its chips into battery electric vehicles. It does do that too, of course. And it is good at it. But it is also banking on a different type of hybrid powertrain. One that is part hydrogen fuel cell, and part lithium-ion battery. https://t.co/MZqirMcCt2 https://t.co/UW8Z1Zv2oJ
# ...

# %% [markdown]
# # Training for June - Dec 2023

# %%
june_2023 = pd.read_csv("../100_data/101_raw/ev_june_dec_2023.csv")

# %%
train2 = june_2023.sample(25, random_state=30).index
train2
# Out:
# Index([5818, 5699, 2403, 3139, 2564, 3321, 1885, 6011, 1600,   22, 4676, 6155,
#        6334, 4012, 2996, 6737, 3156, 5468,   80, 2363, 5052, 1896, 1403, 6723,
#        1786],
#       dtype='int64')

# %%
pd.set_option("display.max_colwidth", None)
june_2023.iloc[train2, :][["UTC_Time", "Tweet_Content"]]
# Out:
#                        UTC_Time  \
# 5818  2023-07-27 13:54:32+00:00
# 5699  2023-07-25 11:54:53+00:00
# 2403  2023-06-20 19:35:36+00:00
# 3139  2023-06-28 14:36:10+00:00
# 2564  2023-06-21 14:00:00+00:00
# 3321  2023-06-29 14:28:52+00:00
# 1885  2023-06-16 15:13:25+00:00
# 6011  2023-07-30 19:06:54+00:00
# 1600  2023-06-14 16:48:45+00:00
# 22    2023-06-01 15:00:36+00:00
# 4676  2023-07-15 12:49:29+00:00
# 6155  2023-08-01 14:41:28+00:00
# 6334  2023-08-02 11:10:12+00:00
# 4012  2023-07-08 12:48:20+00:00
# 2996  2023-06-27 19:20:00+00:00
# 6737  2023-08-05 03:10:10+00:00
# 3156  2023-06-28 17:36:23+00:00
# 5468  2023-07-22 07:42:21+00:00
# 80    2023-06-01 12:23:50+00:00
# 2363  2023-06-20 09:20:00+00:00
# 5052  2023-07-18 16:46:34+00:00
# 1896  2023-06-16 12:41:35+00:00
# 1403  2023-06-12 15:01:37+00:00
# 6723  2023-08-05 22:34:27+00:00
# 1786  2023-06-16 15:28:54+00:00
#
# ...

# %%
train2_manual_labels = [
    "Positive",
    "Positive",
    "Neutral",
    "Neutral",
    "Positive",
    "Neutral",
    "Neutral",
    "Neutral",
    "Positive",
    "Neutral",
    "Positive",
    "Positive",
    "Positive",
    "Positive",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Negative",
    "Neutral",
    "Neutral",
    "Neutral",
    "Negative",
]
assert len(train2_manual_labels) == 25

# %%
june_2023.loc[train2, "Manual_Training_Labels"] = train2_manual_labels
june_2023["Is_Training"] = june_2023["Manual_Training_Labels"].isna().astype(int)
june_2023.loc[train2][["Tweet_Content", "Is_Training", "Manual_Training_Labels"]]
# Out:
#                                                                                                                                                                                                                                                                                                       Tweet_Content  \
# 5818                                             In the UK, the adoption of Electric Vehicles (EVs) has been on the rise, driven by a number of forces. David Kendrick, UHY Manchester CEO, looks into the impact this trend will have on the UK automotive market. https://t.co/8QYryjVEsb https://t.co/jfrIccC1jA
# 5699    More drivers are interested in electric vehicles, and some are taking one for a spin as a sort of “test drive” while on vacation, thanks to them being readily available as rental cars. Learn more: https://t.co/mxSJIDTdie\n\n#EV #ElectricVehicles @evergypower @Hertz @travelks https://t.co/u12EKQ305k
# ...

# %% [markdown]
# # Testing for June - Dec 2023

# %%
test2 = june_2023.sample(13, random_state=40).index
test2
# Out:
# Index([5931, 4571, 2041, 3724, 702, 5246, 5950, 5859, 1937, 1592, 1538, 4516,
#        1194],
#       dtype='int64')

# %%
assert len(set(train2).intersection(set(test2))) == 0  # Make sure no overlap

# %%
pd.set_option("display.max_colwidth", None)
june_2023.iloc[test2, :][["UTC_Time", "Tweet_Content"]]
# Out:
#                        UTC_Time  \
# 5931  2023-07-30 14:08:09+00:00
# 4571  2023-07-13 18:07:34+00:00
# 2041  2023-06-17 02:15:13+00:00
# 3724  2023-07-03 12:49:28+00:00
# 702   2023-06-06 17:17:29+00:00
# 5246  2023-07-19 13:06:12+00:00
# 5950  2023-07-30 12:38:39+00:00
# 5859  2023-07-28 14:27:10+00:00
# 1937  2023-06-17 15:06:00+00:00
# 1592  2023-06-13 23:00:00+00:00
# 1538  2023-06-13 16:55:22+00:00
# 4516  2023-07-13 15:43:22+00:00
# 1194  2023-06-11 23:19:16+00:00
#
#                                                                                                                                                                                                                                                                                                          Tweet_Content
# ...

# %%
test2_manual_labels = [
    "Negative",
    "Neutral",
    "Neutral",
    "Neutral",
    "Positive",
    "Positive",
    "Negative",
    "Neutral",
    "Neutral",
    "Neutral",
    "Neutral",
    "Positive",
    "Neutral",
]
assert len(test2_manual_labels) == 13

# %%
june_2023.loc[test2, "Manual_Testing_Labels"] = test2_manual_labels
june_2023["Is_Testing"] = june_2023["Manual_Testing_Labels"].isna().astype(int)
june_2023 = june_2023.loc[test2][
    ["Tweet_Content", "Is_Testing", "Manual_Testing_Labels"]
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 june_2023["Manual_Testing_Labels"] = test2_manual_labels
#       2 june_2023["Is_Testing"] = june_2023["Manual_Testing_Labels"].isna().astype(int)
#       3 june_2023.loc[test2][["Tweet_Content", "Is_Testing", "Manual_Testing_Labels"]]
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.